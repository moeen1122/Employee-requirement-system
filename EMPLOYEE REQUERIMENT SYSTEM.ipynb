# %%
import pandas as pd
df=pd.DataFrame({'Name':[],'Mobile number':[],'Address':[],'Pincode':[],'Gender':[],'Language':[],'UG degree':[],
                'Branch':[],'UG percentage':[],'12th percentage':[],'10th percentage':[],'Pre company':[],'Year of exeriance':[],
                'Pre package':[],'Feedback':[]})
df.to_csv("employe.csv",index=None)

# %%
from tkinter import *
import tkinter
from tkinter import messagebox


def raise_frame(frame):
    frame.tkraise()

root = Tk()
root.geometry("1000x1000")
#root.config(bg="red")

f1 = Frame(root)
f2 = Frame(root)
f3 = Frame(root)
f4 = Frame(root)

for frame in (f1, f2, f3, f4):
    frame.grid(row=0, column=0 ,sticky='news')

############################################## ADMIN LOGIN PAGE  ##############################################################
def ok():
    uname=e22.get()
    password=e23.get()
    if(uname==""and password==""):
        messagebox.showinfo("","blank not allowed")
        
    elif(uname=="admin" and password=="123"):
        messagebox.showinfo("","Login Success")
        print(pd.read_csv("employe.csv"))
        
    else:
        messagebox.showinfo("","incorrect username and password")

Label(f1,text="EMPLOYEE REQUIREMENT SYSTEM",font=100,fg="blue",height=3,width=50,bg="orange").grid(row=2,column=2)
Label(f1,text="Admin login page :",font=50,fg="red").grid(row=4,column=1)
Label(f1,text="").grid(row=5,column=1)

Label(f1,text="username",font=100).grid(row=10,column=0)
Label(f1,text="").grid(row=11,column=0)
Label(f1,text="password",font=100).grid(row=15,column=0)
Label(f1,text="").grid(row=16,column=0)

e22=Entry(f1,font=50)
e22.grid(row=10,column=1)

e23=Entry(f1,font=50)
e23.grid(row=15,column=1)
e23.config(show="*")



Button(f1,text="Login",command=ok,height=1,width=9,fg="red").grid(row=20,column=1)
Label(f1,text="").grid(row=21,column=1)
Label(f1,text="Click below for applying the job",font=50,fg="blue").grid(row=22,column=1)
Label(f1,text="").grid(row=23,column=1)
Button(f1, text="APPLY JOB",fg="blue", command=lambda:raise_frame(f2)).grid(row=24,column=1)

#################################################  APPLICATION FORAM  #########################################################

Label(f2,text="PERSONAL DETAILS",font=100,fg="blue").grid(row=8,column=1)
Label(f2,text=" ").grid(row=9  ,column=0 )       
l1=Label(f2, text="Enter Name",font=100).grid(row=10,column=0)
v1=StringVar()
e1=Entry(f2,textvariable=v1,font=100).grid(row=10,column=1)
Label(f2,text=" ").grid(row= 11 ,column=0 )
l2=Label(f2, text="Enter Mobile Number",font=100).grid(row=12,column=0)
v2=StringVar()
e2=Entry(f2,textvariable=v2,font=100).grid(row=12,column=1)
Label(f2,text=" ").grid(row=13 ,column=0 )
l3=Label(f2, text="Enter Adders",font=100).grid(row=14,column=0)
v3=StringVar()
e3=Entry(f2,textvariable=v3,font=100).grid(row=14,column=1)
Label(f2,text=" ").grid(row=15,column=0 )
l44=Label(f2, text="Enter Pincode",font=100).grid(row=16,column=0)
v44=StringVar()
e44=Entry(f2,textvariable=v44,font=100).grid(row=16,column=1)
Label(f2,text=" ").grid(row=17,column=0 )
l4=Label(f2, text="Select gender",font=100).grid(row=18,column=0)
v=IntVar()
r1=Radiobutton(f2,text="Male",font=100,variable=v,value=1).grid(row=18,column=1)
r2=Radiobutton(f2,text="FeMale",font=100,variable=v, value=2).grid(row=18,column=2)
r3=Radiobutton(f2,text="others",font=100,variable=v,value=3).grid(row=18,column=3)
Label(f2,text=" ").grid(row=19,column=0 )
l5=Label(f2,text="Select languages",font=100).grid(row=20,column=0)
v4,v5,v6=IntVar(), IntVar(), IntVar()
c1=Checkbutton(f2,text="English",font=100,variable=v4,onvalue=1, offvalue=0)
c1.grid(row=20,column=1)
c2=Checkbutton(f2,text="Hindi",font=100,variable=v5, onvalue=1, offvalue=0)
c2.grid(row=20,column=2)
c3=Checkbutton(f2,text="Punjabi",font=100,variable=v6, onvalue=1, offvalue=0)
c3.grid(row=20,column=3)
Label(f2,text=" ").grid(row=21  ,column=0 )
#Button(f2,text="click",font=100,command=check).grid(row=22,column=2)
Button(f2, text='back',font=100, command=lambda:raise_frame(f1)).grid(row=22,column=0)
Button(f2, text='next', command=lambda:raise_frame(f3)).grid(row=22,column=2)
################################################ VALIDATIONS ########################################################
def check():
        s,e="",""
        if(v1.get()==""):
            e+="Please enter a name\n"
        else:
            s+=v1.get()
        if(not(v2.get().isdigit()) or len(v2.get())!=10):
            e+="Please enter a valid mobile number\n"
        else:
            s+=v2.get()
        if(v3.get()==""):
            e+="Please enter Addres\n"
        else:
            s+=v3.get()
        if((not(v44.get().isdigit()) or len(v44.get())!=6)):
            e+="please enter valid pincode\n"
        else:
            s+=v44.get()
        if(v.get()):
            if(v.get()==1):
                s+= "Male"
            if(v.get()==2):
                s+="Female"
            if(v.get()==3):
                s+="others"
        else:
            e+="Please select a gender\n"
        if(v4.get()==0 and v5.get()==0 and v6.get()==0):
            e+="Atleast select one subject\n"
        else:
            if(v4.get()):
                s+=" english"
            if(v5.get()):
                s+="hindi"
            if(v6.get()):
                s+="Punjabi"
        if(not(v8.get().isalpha())):
            e+="please enter UG Degree\n"
        else:
            s+=v8.get()
        if(not(v9.get().isalpha())):
            e+="please enter Branch\n"
        else:
            s+=v9.get()
        if(not(v10.get().isdigit())):
            e+="please enter UG percentage\n"
        else:
            s+=v10.get()
        if(not(v11.get().isalpha())):
            e+="please enter 12th school name\n"
        else:
            s+=v11.get()
        if(not(v12.get().isdigit())):
            e+="please enter 12th percentage\n"
        else:
            s+=v12.get()
        if(not(v13.get().isalpha())):
            e+="please enter 10th school name\n"
        else:
            s+=v13.get()
        if(not(v14.get().isdigit())):
            e+="please enter 10th percentage\n"
        else:
            s+=v14.get()
        if(not(v15.get().isalpha())):
            e+="please enter company name\n"
        else:
            s+=v15.get()
        if(not(v16.get().isdigit())):
            e+="please enter experience\n"
        else:
            s+=v16.get()
        if(not(v17.get().isdigit())):
            e+="please enter pre package\n"
        else:
            s+=v17.get()
        if(e!=""):
                messagebox.showerror("error",e)
        else:
            messagebox.showinfo("Data",s)
########################################## CONNECTED TO BACKEND TO CSV FILE ####################################################
            df=pd.read_csv("employe.csv")
            cn=list(df.columns)
            df=df.append(pd.DataFrame({cn[0]:[v1.get()],
                           cn[1]:[v2.get()],
                           cn[2]:[v3.get()],
                           cn[3]:[v44.get()],
                            cn[4]:[v.get()],
                            cn[5]:[v4.get()],
                            cn[6]:[v8.get()],
                            cn[7]:[v9.get()],
                            cn[8]:[v10.get()],
                            cn[9]:[v12.get()],
                            cn[10]:[v13.get()],
                            cn[11]:[v15.get()],
                            cn[12]:[v16.get()],
                            cn[13]:[v17.get()],
                            cn[14]:[v18.get()]}))
            df.to_csv("employe.csv",index=None)

Label(f3,text="QUALIFICATION DETAILS",font=100,fg="blue").grid(row=5,column=2)
Label(f3,text=" ").grid(row=6 ,column=1)
l7=Label(f3,text="UG Degree",font=100).grid(row=7,column=0)
v8=StringVar()
e5=Entry(f3,textvariable=v8,font=100).grid(row=7,column=1)
Label(f3,text=" ").grid(row=8 ,column=1 )
l8=Label(f3,text="Branch",font=100).grid(row=9,column=0)
v9=StringVar()
e6=Entry(f3,textvariable=v9,font=100).grid(row=9,column=1)
Label(f3,text=" ").grid(row=10 ,column=1 )
l9=Label(f3,text="UG percentage",font=100).grid(row=11,column=0)
v10=StringVar()
e7=Entry(f3,textvariable=v10,font=100).grid(row=11,column=1)
Label(f3,text=" ").grid(row=12 ,column=1 )
l10=Label(f3,text="12th school name",font=100).grid(row=13,column=0)
v11=StringVar()
e8=Entry(f3,textvariable=v11,font=100).grid(row=13,column=1)
Label(f3,text=" ").grid(row=14 ,column=1 )
l11=Label(f3,text="12th percentage",font=100).grid(row=15,column=0)
v12=StringVar()
e9=Entry(f3,textvariable=v12,font=100).grid(row=15,column=1)
Label(f3,text=" ").grid(row=16 ,column=1 )
l12=Label(f3,text="10th school name",font=100).grid(row=17,column=0)
v13=StringVar()
e10=Entry(f3,textvariable=v13,font=100).grid(row=17,column=1)
Label(f3,text=" ").grid(row=18 ,column=1 )
l13=Label(f3,text="10th percentage",font=100).grid(row=19,column=0)
v14=StringVar()
e11=Entry(f3,textvariable=v14,font=100).grid(row=19,column=1)
Label(f3,text=" ").grid(row=20 ,column=1 )
Button(f3, text='back', command=lambda:raise_frame(f2)).grid(row=22,column=0)#pack(side='left')
Button(f4,text="submit",font=100,command=check).grid(row=22,column=2)

Button(f3, text='Next', command=lambda:raise_frame(f4)).grid(row=22,column=2)#pack(side='left')

#Label(f4, text='FRAME 4').grid(row=2,column=1)
Label(f4,text=" ").grid(row=3 ,column=1 )
l14=Label(f4,text="Previous company name",font=100).grid(row=5,column=0)
v15=StringVar()
e12=Entry(f4,textvariable=v15,font=100).grid(row=5,column=1)
Label(f4,text=" ").grid(row=6 ,column=1 )
l15=Label(f4,text="Year of Experience",font=100).grid(row=7,column=0)
v16=StringVar()
e13=Entry(f4,textvariable=v16,font=100).grid(row=7,column=1)
Label(f4,text=" ").grid(row=8 ,column=1 )
l16=Label(f4,text="previous package",font=100).grid(row=9,column=0)
v17=StringVar()
e14=Entry(f4,textvariable=v17,font=100).grid(row=9,column=1)
Label(f4,text=" ").grid(row=10 ,column=1 )
Label(f4,text="feedback :",font=100).grid(row=11,column=0)
v18=StringVar()
Label(f4,text=" ").grid(row=12 ,column=1 )
e15=Entry(f4,textvariable=v18,font=100).grid(row=13,column=0)
Label(f4,text=" ").grid(row=14 ,column=1 )
Button(f4, text='HOME PAGE', command=lambda:raise_frame(f1)).grid(row=1,column=1)
Button(f4, text='back',font=100, command=lambda:raise_frame(f3)).grid(row=22,column=0)

raise_frame(f1)
root.mainloop()
# Out:
# Empty DataFrame
# Columns: [Name, Mobile number, Address, Pincode, Gender, Language, UG degree, Branch, UG percentage, 12th percentage, 10th percentage, Pre company, Year of exeriance, Pre package, Feedback]
# Index: []

# %%
(5,9,11,3,33,14)
